# %%
#import the requried pacages
import pandas as pd
import numpy as np

# %% [markdown]
# Importing File or including file

# %%
df=pd.read_csv("Online Retail.csv")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# **df.shape**: Returns a tuple (rows, columns)

# %%
df.shape
# Out:
# (541909, 8)

# %%
# df.head() returns top 5 rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
#df.tail() returnd bottum 5 elements
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85     12680.0  France
# 541905  12/9/11 12:50       2.10     12680.0  France
# 541906  12/9/11 12:50       4.15     12680.0  France
# 541907  12/9/11 12:50       4.15     12680.0  France
# 541908  12/9/11 12:50       4.95     12680.0  France

# %%
df.info
# Out:
# <bound method DataFrame.info of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  531283.000000                         531283  531283.000000
# mean       10.655299  2011-07-04 18:15:33.177910016       3.898954
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         1.000000            2011-03-28 11:59:00       1.250000
# 50%         3.000000            2011-07-20 12:01:00       2.080000
# 75%        10.000000            2011-10-19 12:35:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       156.830617                            NaN      35.876279
#
#           CustomerID          Month           Year            Day  \
# count  531283.000000  531283.000000  531283.000000  531283.000000
# mean    15258.592197       7.560242    2010.921543      15.024706
# min     12346.000000       1.000000    2010.000000       1.000000
# 25%     14388.000000       5.000000    2011.000000       7.000000
# ...

# %%
df.Country.value_counts()
#Number of unit sold per country
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df.CustomerID.value_counts()
#number of purchases by customer
# Out:
# CustomerID
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: count, Length: 4372, dtype: int64

# %%
print(df.isnull().sum())
#sum of number null values per column
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Filling 'Unknown' in place of null values
df.Description = df.Description.fillna("unknown")
print(df.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['CustomerID'] = df['CustomerID'].fillna(df['CustomerID'].median())
print(df.isnull().sum())
#will properly fill missing values in the CustomerID column with its median value.
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# Filter out rows where 'Quantity' is less than 0 (negative)
df = df[df['Quantity'] >= 0]

# Filter out rows where 'UnitPrice' is less than 0 (negative)
df = df[df['UnitPrice'] >= 0]

# %%
# Convert 'InvoiceDate' to datetime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Extract useful time-based features
#df['DayOfWeek'] = df['InvoiceDate'].dt.dayofweek  # 0=Monday, 6=Sunday
df['Month'] = df['InvoiceDate'].dt.month
df['Year'] = df['InvoiceDate'].dt.year
df['Day'] = df['InvoiceDate'].dt.day
df
# Out:
# <ipython-input-14-412e0b60b9d2>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# ...

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']
#creating new coloumn for calculating Revenue
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Plotting line plot for 'Revenue Vs Year'
plt.plot(df.InvoiceDate,df.Revenue , color='red', marker='o')
plt.title('Revenue Vs Year', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.grid(True)
plt.show()

# %%
##Plotting line plot for 'Revenue Vs Month'
plt.plot(df.Month,df.Revenue , color='red', marker='o')
plt.title('Revenue Vs Month', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.grid(True)
plt.show()

# %%
#plotting histogram for displaying Distribution of Customer Spending
plt.hist(df['CustomerID'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Customer Spending')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Group by 'Country' and sum 'Revenue' to get the total revenue per country
country_revenue = df.groupby('Country')['Revenue'].sum()

# Create a bar chart for Country vs Revenue
plt.figure(figsize=(8, 6))
country_revenue.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Country vs Total Revenue')
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.tight_layout()  # Adjust layout for better visibility
plt.show()

# %%
# Group by 'Country' and sum 'Revenue' to get the total revenue per country
country_revenue = df.groupby('Country')['Revenue'].sum()

# Get the top 10 countries by revenue
top_10_countries = country_revenue.nlargest(10)

# Create a bar chart for Country vs Revenue
plt.figure(figsize=(8, 6))
top_10_countries.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Countries by Total Revenue')
plt.xlabel('Country')
plt.ylabel('Total Revenue(in million)')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.tight_layout()  # Adjust layout for better visibility
plt.show()

# %%
# Aggregate customer data
df_customers = df.groupby('CustomerID').agg({
    'Revenue': 'sum',  # Total spending
    'InvoiceNo': 'count'  # Number of purchases # Changed 'TransactionID' to 'InvoiceNo'
}).reset_index()

# Rename columns for clarity
df_customers.rename(columns={'Revenue': 'Total_Spend', 'InvoiceNo': 'Purchase_Frequency'}, inplace=True)
# Changed 'TransactionID' to 'InvoiceNo'

# %%
# Merge the aggregated data (df_customers) with the original DataFrame (df)
# using 'CustomerID' as the key and performing a left merge.
# This adds the aggregated columns (Total_Spend, Purchase_Frequency)
# to the original DataFrame.
df = pd.merge(df, df_customers, on='CustomerID', how='left')

# Now, scale the features 'Total_Spend' and 'Purchase_Frequency'
# using StandardScaler. This is often done in preprocessing for
# machine learning algorithms like K-Means to ensure that features
# with different scales contribute equally to the distance calculations.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[['Total_Spend', 'Purchase_Frequency']])

# %% [markdown]
# **K-Means Clustering**
#
# K-Means is a popular choice for customer segmentation. First, determine the optimal number of clusters using the Elbow Method.

# %%
# Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans  # Import KMeans for clustering

# Initialize an empty list to store WCSS values
wcss = []

# Iterate through different cluster numbers (1 to 10)
for i in range(1, 11):
    # Create a KMeans model with 'i' clusters, random state for reproducibility, and 10 initializations
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    # Fit the KMeans model to the scaled features
    kmeans.fit(scaled_features)
    # Append the within-cluster sum of squares (inertia) to the list
    wcss.append(kmeans.inertia_)

# Create a plot to visualize the Elbow method
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-')  # Plot WCSS values against cluster numbers
plt.xlabel('Number of Clusters')  # Label the x-axis
plt.ylabel('WCSS')  # Label the y-axis
plt.title('Elbow Method for Optimal K')  # Set the title of the plot
plt.show()  # Display the plot

# %% [markdown]
# **Applying K-Means Clustering**

# %%
# Apply K-Means with optimal clusters (assume K=3)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# Analyze segment statistics
cluster_summary = df.groupby('Cluster').agg({'Total_Spend': 'mean', 'Purchase_Frequency': 'mean', 'CustomerID': 'count'}).rename(columns={'CustomerID': 'Customer_Count'})
print(cluster_summary)
# Out:
#           Total_Spend  Purchase_Frequency  Customer_Count
# Cluster
# 0        1.760022e+06       133630.000000          133630
# 1        4.207194e+03          289.090263          363207
# 2        8.869143e+04         4601.338965           34446

# %% [markdown]
# **Visualization of Clusters**:
#
# Use scatter plots to analyze customer segmentation.

# %%
import seaborn as sns

# Create a scatter plot to visualize customer segments
plt.figure(figsize=(8,6))  # Set the figure size
sns.scatterplot(
    data=df,  # Use the DataFrame 'df' as the data source
    x='Total_Spend',  # Plot 'Total_Spend' on the x-axis
    y='Purchase_Frequency',  # Plot 'Purchase_Frequency' on the y-axis
    hue='Cluster',  # Color points based on the 'Cluster' column
    palette='viridis',  # Use the 'viridis' color palette
    alpha=0.7  # Set transparency to 0.7
)
plt.title('Customer Segments (K-Means)')  # Set the title of the plot
plt.xlabel('Total Spend')  # Label the x-axis
plt.ylabel('Purchase Frequency')  # Label the y-axis
plt.show()  # Display the plot

# %% [markdown]
# **Estimating Customer Lifetime Value (CLV)**:
#
# CLV helps predict the total revenue a business can expect from a customer over their entire relationship. Below are two common approaches

# %%
import datetime as dt

# Convert InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
latest_date = df['InvoiceDate'].max()  # Most recent transaction date

# Calculate RFM metrics
# Changed 'TransactionID' to 'InvoiceNo' as it's the actual column name in your DataFrame
rfm = df.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (latest_date - x.max()).days,  # Recency
    'InvoiceNo': 'count',  # Frequency
    'Revenue': 'sum'  # Monetary
}).reset_index()

# Rename columns
rfm.rename(columns={'InvoiceDate': 'Recency', 'InvoiceNo': 'Frequency', 'Revenue': 'Monetary'}, inplace=True) # Changed 'TransactionID' to 'InvoiceNo'

# Estimate CLV (Simple method: Avg Monetary * Frequency)
rfm['CLV'] = rfm['Monetary'] * rfm['Frequency']

print(rfm.head())  # Check RFM and CLV values
# Out:
#    CustomerID  Recency  Frequency  Monetary        CLV
# 0     12346.0      325          1  77183.60   77183.60
# 1     12347.0        1        182   4310.00  784420.00
# 2     12348.0       74         31   1797.24   55714.44
# 3     12349.0       18         73   1757.55  128301.15
# 4     12350.0      309         17    334.40    5684.80
